# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# a = np.loadtxt("/home/vidur/Documents/run_N2lFinal-tag-Training_accuracy.csv")
a = pd.read_csv("/home/vidur/Desktop/run_N3l0.005m0.5Size300Skip6-Loss-F-tag-Training_accuracy.csv")
b = pd.read_csv("/home/vidur/Desktop/run_N3l0.005m0.5Size300Skip6-Loss-F-tag-Validation_accuracy.csv")

# %%
a = a.values[:,[1,2]]
b = b.values[:,[1,2]]

# %%
# np.argmin(a[:,0])
alax  = b[:,1]
np.argmax(alax)
np.max(alax)
# Out:
# 0.6823999881744385

# %%
plt.plot(a[:,0],a[:,1], label = "Training Accuracy")
plt.plot(b[:,0],b[:,1], label = "Test Accuracy" )
plt.xlabel("Epochs")
plt.annotate('Max : .682', xy=(9, 0.6823999881744385
), xytext=(9, 0.6823999881744385
+.05),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
# plt.clf()
plt.ylabel("Accuracy")
plt.title("Question 3c")
plt.savefig("Question3c.png")
plt.show()
